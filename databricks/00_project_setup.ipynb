# %%
# Finance Risk & Profitability Analytics Platform
# Version: V1
# Purpose: End-to-end financial analytics platform using Databricks

PROJECT_NAME = "Finance Risk & Profitability Analytics Platform"
PROJECT_VERSION = "V1"

print(PROJECT_NAME)
print(f"Version: {PROJECT_VERSION}")

# %%
print("Python execution: OK")

df = spark.range(10)

print("Spark execution: OK")
display(df)

# %%
catalog_name = "workspace"
schema_name = "finance_analytics"

print(f"Catalog: {catalog_name}")
print(f"Schema: {schema_name}")

# %%
volume_path = "/Volumes/workspace/finance_analytics/finance_raw"

print(f"Raw data volume: {volume_path}")
